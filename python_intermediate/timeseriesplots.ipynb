# %%
from datetime import datetime
date_var = datetime(2020,12,1)
print(date_var)
# Out:
# 2020-12-01 00:00:00

# %%
## MATH operations with dates
delta_t = (datetime.now() - date_var)
print(delta_t); print(type(delta_t))
# Out:
# 834 days, 16:21:38.956117
# <class 'datetime.timedelta'>

# %%
## DATE FORMATING with strftime() method
dt_str = date_var.strftime('%B %d %Y')
dt_str = date_var.strftime('%d/%m/%Y')
print(dt_str)
# Out:
# 01/12/2020

# %%
import numpy as np
import pandas as pd
np.random.seed(50)

def random_walk(n_steps):
    step= 0.5 - np.random.random(n_steps)
    return np.cumsum(step)

## date_range() generates a equality spaced time range
date =pd.date_range('1/1/2019', '12/31/2019', freq='D')
data = {'a':random_walk(365), 'b':random_walk(365)}
sales_data=pd.DataFrame(data,index=date)
sales_data ## dataframe with 365 days and two variables
# Out:
#                    a         b
# 2019-01-01  0.005398  0.293756
# 2019-01-02  0.277315  0.483571
# 2019-01-03  0.521841  0.034775
# 2019-01-04  0.625511 -0.307947
# 2019-01-05  0.748196 -0.503416
# ...              ...       ...
# 2019-12-27  3.147526 -0.806121
# 2019-12-28  3.596974 -0.723909
# 2019-12-29  3.503456 -1.032693
# 2019-12-30  3.790108 -0.561819
# 2019-12-31  3.958460 -0.467491
#
# [365 rows x 2 columns]

# %%
## installing matplotlib
# !pip install matplotlib

# %%
## importing matplotlib module
import matplotlib.pyplot as plt

# %%
## plotting a time series with 2 variables
sales_data.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
x_values = [1, 3, 5, 9, 20]
y_values = [2, 5, 6, 9, 14]

plt.plot(x_values, y_values)
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Line Chart')

plt.show()

# %%
# Make a random dataset:
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
y_pos = np.arange(len(bars))

# Create bars
plt.bar(bars, height)

# Create names on the x-axis
plt.xticks()
plt.title('Bar Chart')
plt.xlabel('Person')
plt.ylabel('Height')

# Show graphic
plt.show()

# %%
plt.scatter(x_values, y_values)
plt.show()

# %%
x =  np.random.randn(1000) ## randn returns a normal distrubution values
plt.hist(x, bins= 20)
plt.title('Normal Dist')
plt.show()

# %%
## PLOTTING FROM A DATAFRAME
p = sales_data.plot.hist()
type(p)
# Out:
# matplotlib.axes._axes.Axes

# %%
sales_data = pd.read_csv('sales_data_sample.csv', encoding_errors= 'replace', dtype={'ORDERNUMBER': str})

# %%
sales_data.head()
# Out:
#   ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0       10107               30      95.70                2  2871.00
# 1       10121               34      81.35                5  2765.90
# 2       10134               41      94.74                2  3884.34
# 3       10145               45      83.26                6  3746.70
# 4       10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
## CONVERTING A COLUMN TO DATE TYPE and formatting it
sales_data['ORDERDATE'] = pd.to_datetime(sales_data['ORDERDATE']).dt.strftime('%d/%m/%Y')

# %%
sales_data.head()
# Out:
#   ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0       10107               30      95.70                2  2871.00
# 1       10121               34      81.35                5  2765.90
# 2       10134               41      94.74                2  3884.34
# 3       10145               45      83.26                6  3746.70
# 4       10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0  24/02/2003  Shipped       1         2     2003  ...
# 1  07/05/2003  Shipped       2         5     2003  ...
# 2  01/07/2003  Shipped       3         7     2003  ...
# 3  25/08/2003  Shipped       3         8     2003  ...
# 4  10/10/2003  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# 1             59 rue de l'Abbaye           NaN          Reims   NaN
# ...

# %%
# !pip install seaborn

# %%
## SEABORN  / PLOTTING / GRAPHS
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
## IMPORTING DATASETS
flights = pd.read_csv("seaborn-data-master/flights.csv")
titanic = pd.read_csv("seaborn-data-master/titanic.csv")
tips=pd.read_csv("seaborn-data-master/tips.csv")
iris= pd.read_csv("seaborn-data-master/iris.csv")

# %%
#try bar blot
sns.barplot(x="class",y="survived",data=titanic)
plt.show()

# %%
sns.boxplot(x="class",y="age",data=titanic)
plt.show()

# %%
sns.violinplot(x="class",y="age",data=titanic)
plt.show()

# %%
flights = flights.pivot("month","year","passengers")
sns.heatmap(flights,cmap="YlGnBu")
plt.show()
# Out:
# C:\Users\Lucas\AppData\Local\Temp\ipykernel_5548\91112118.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot("month","year","passengers")

# %%
sns.jointplot(x="total_bill", y="tip",data=tips, kind='reg')
plt.show()

# %%
sns.pairplot(iris,hue="species")
plt.show()

# %%
x = lambda y:int(y)*int(y)
print(x("2"))
# Out:
# 4

# %%
import pandas as pd

# %%
appledf = pd.read_csv('apple-historical-data.csv', parse_dates = ['Date'], index_col='Date') ## parse_date is useful to convert dates to a single format

# %%
appledf.head()
# Out:
#            Close/Last    Volume      Open      High        Low
# Date
# 2023-03-16    $155.85  76254420   $152.16   $156.46    $151.64
# 2023-03-15    $152.99  77167870   $151.19  $153.245    $149.92
# 2023-03-14    $152.59  73695890   $151.28   $153.40    $150.10
# 2023-03-13    $150.47  84457120  $147.805   $153.14    $147.70
# 2023-03-10    $148.50  68572400   $150.21   $150.94  $147.6096

# %%
appledf['Close/Last'] = appledf['Close/Last'].str.replace('$', '')
# Out:
# C:\Users\Lucas\AppData\Local\Temp\ipykernel_10720\350624049.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   appledf['Close/Last'] = appledf['Close/Last'].str.replace('$', '')

# %%
appledf.head()
# Out:
#            Close/Last    Volume      Open      High        Low
# Date
# 2023-03-16     155.85  76254420   $152.16   $156.46    $151.64
# 2023-03-15     152.99  77167870   $151.19  $153.245    $149.92
# 2023-03-14     152.59  73695890   $151.28   $153.40    $150.10
# 2023-03-13     150.47  84457120  $147.805   $153.14    $147.70
# 2023-03-10     148.50  68572400   $150.21   $150.94  $147.6096

# %%
appledf['Close/Last'] = appledf['Close/Last'].apply(lambda x: float(x))

# %%
appledf['Close/Last'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
## asfreq() 
appledf = appledf.asfreq('H', method='pad')

# %%
## I can create a dates column if I know the starting and ending date.
firtsDate = appledf.index.min()
lastDate = appledf.index.max()
dateRange = pd.date_range(appledf.index.min(),  appledf.index.max(), freq='B') ## 'B' returns only business days
appledf['date2'] = pd.date_range(dateRange.min(),  dateRange.max(), freq='H')

# %%
# Out:
# month
# 1     136.179731
# 2     150.740179
# 3     161.798752
# 4     166.268708
# 5     148.195981
# 6     139.112250
# 7     150.081586
# 8     166.741223
# 9     153.304875
# 10    145.460591
# 11    145.581250
# 12    136.621882
# Name: Close/Last, dtype: float64

# %%
## I can reset the index like this to a default value
appledf = appledf.reset_index(drop=True) ## this will DELETE the index column because of drop=True
appledf.head()
# Out:
#    Close/Last     Volume     Open     High      Low               date2  month
# 0      160.62   75615380  $158.61  $161.00  $157.63 2022-03-17 00:00:00      3
# 1      163.98  123511700  $160.51  $164.48  $159.76 2022-03-17 01:00:00      3
# 2      163.98  123511700  $160.51  $164.48  $159.76 2022-03-17 02:00:00      3
# 3      163.98  123511700  $160.51  $164.48  $159.76 2022-03-17 03:00:00      3
# 4      163.98  123511700  $160.51  $164.48  $159.76 2022-03-17 04:00:00      3

# %%
## I now assigned the date2 column as new index column
appledf.set_index(appledf['date2'], inplace=True)
appledf.head()
# Out:
#                      Close/Last     Volume     Open     High      Low  \
# date2
# 2022-03-17 00:00:00      160.62   75615380  $158.61  $161.00  $157.63
# 2022-03-17 01:00:00      163.98  123511700  $160.51  $164.48  $159.76
# 2022-03-17 02:00:00      163.98  123511700  $160.51  $164.48  $159.76
# 2022-03-17 03:00:00      163.98  123511700  $160.51  $164.48  $159.76
# 2022-03-17 04:00:00      163.98  123511700  $160.51  $164.48  $159.76
#
#                                   date2  month
# date2
# 2022-03-17 00:00:00 2022-03-17 00:00:00      3
# 2022-03-17 01:00:00 2022-03-17 01:00:00      3
# 2022-03-17 02:00:00 2022-03-17 02:00:00      3
# 2022-03-17 03:00:00 2022-03-17 03:00:00      3
# 2022-03-17 04:00:00 2022-03-17 04:00:00      3

# %%
## SUBSTRACTING DIFFERENCES BETWEEN DATE SERIES with DIFFERENCE() method CHECKKKKKKKKkkk
range1 = appledf['date2']
range2 = pd.date_range('2022-05-01', '2023-01-01', freq='H')
# display(range3) ## 5881 rows
# display(range1) ## 8737 rows
rng = range2.difference(range1)
rng
# Out:
# DatetimeIndex([], dtype='datetime64[ns]', freq=None)

# %%
## CALCULATIONG AVG PRICE CLOSE PER MONTH (HISTORICAL, AVG CALCULATED FOR ALL YEARS)
appledf['month'] = appledf['date2'].apply(lambda x: x.month)
appledf.groupby(['month'])['Close/Last'].mean()
# Out:
# month
# 1     136.179731
# 2     150.740179
# 3     161.798752
# 4     166.268708
# 5     148.195981
# 6     139.112250
# 7     150.081586
# 8     166.741223
# 9     153.304875
# 10    145.460591
# 11    145.581250
# 12    136.621882
# Name: Close/Last, dtype: float64

# %%
## this allows to group data by time intervals
## the DataFrame must have a datetime-like index
appledf['Close/Last'].resample("M").mean()
# Out:
# Date
# 2022-03-31    171.340000
# 2022-04-30    166.821000
# 2022-05-31    148.430476
# 2022-06-30    139.798571
# 2022-07-31    149.670500
# 2022-08-31    166.885217
# 2022-09-30    153.002857
# 2022-10-31    145.013333
# 2022-11-30    145.843333
# 2022-12-31    137.876667
# 2023-01-31    135.779000
# 2023-02-28    150.968421
# 2023-03-31    150.961667
# Freq: M, Name: Close/Last, dtype: float64

# %%
############ WORKING WITH SQL ########################
import sqlite3 ## mysql db build-in in python by default

# %%
# Connect to database
# connect() creates a database
# takes the path to the database file as an argument. If the
# file does not exist, the sqlite3 module will create an empty database. 
conn = sqlite3.connect('lucasdb.db')

#create a curser object
# The cursor is what you
# use to send SQL commands to your database via its execute() function. 
c = conn.cursor()

#create a new table
c.execute('''CREATE TABLE STOCKS(DATE TEXT,QTY REAL, PRICE REAL)''')


#INSERT SOME DATA
c.execute("INSERT INTO STOCKS VALUES('2023-03-05',5,35.14)")
c.execute("INSERT INTO STOCKS VALUES('2023-03-06',100,36.14)")
conn.commit()

c.close()
conn.close()

# %%
conn = sqlite3.connect('lucasdb.db')

c =conn.cursor()
c.execute('SELECT * FROM STOCKS')

rows= c.fetchall()

for row in rows:
    print(row)

c.close()
conn.close()
# Out:
# ('2023-03-05', 5.0, 35.14)
# ('2023-03-06', 100.0, 36.14)
